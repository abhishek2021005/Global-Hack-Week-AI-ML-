# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishek2021005/Global-Hack-Week-AI-ML-/blob/main/linegraph%2Bbarchart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# example dataset
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
population = [7000, 7500, 8000, 8500, 9000, 9500, 10000, 10500, 11000, 11500, 12000]

# plotting the line graph
plt.plot(years, population)

# naming the x axis
plt.xlabel("Year")

# naming the y axis
plt.ylabel("Population")

# giving a title to the graph
plt.title("Population growth over the years")

# showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# example dataset
products = ['Product A', 'Product B', 'Product C', 'Product D']
sales = [200, 150, 300, 100]

# plotting the bar graph
plt.bar(products, sales)

# naming the x axis
plt.xlabel("Product")

# naming the y axis
plt.ylabel("Sales (in units)")

# giving a title to the graph
plt.title("Sales of different products")

# showing the plot
plt.show()
